# %%
import pandas as pd

# %% [markdown]
# # 1.DATA_COLLECTION?
# # DATA FROM KAGGLE
# # Tennessee middle schools.csv

# %%
dataset=pd.read_csv("Tennessee middle schools.csv")

# %%
dataset
# Out:
#                              name  school_rating  size  reduced_lunch  \
# 0     Allendale Elementary School              5   851             10
# 1             Anderson Elementary              2   412             71
# 2                Avoca Elementary              4   482             43
# 3                   Bailey Middle              0   394             91
# 4             Barfield Elementary              4   948             26
# ..                            ...            ...   ...            ...
# 342  Winfree Bryant Middle School              3   611             57
# 343    Winstead Elementary School              5   515              8
# 344           Woodland Elementary              4   424             55
# 345        Woodland Middle School              5   866              2
# 346                 Wright Middle              0   829             89
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %% [markdown]
# # 2.DATA_PREPROCESSING?
# # using fillna function for  DATASET TA PREPROCESSING

# %%
dataset.isnull()
# Out:
#       name  school_rating   size  reduced_lunch  state_percentile_16  \
# 0    False          False  False          False                False
# 1    False          False  False          False                False
# 2    False          False  False          False                False
# 3    False          False  False          False                False
# 4    False          False  False          False                False
# ..     ...            ...    ...            ...                  ...
# 342  False          False  False          False                False
# 343  False          False  False          False                False
# 344  False          False  False          False                False
# 345  False          False  False          False                False
# 346  False          False  False          False                False
#
#      state_percentile_15  stu_teach_ratio  school_type  avg_score_15  \
# ...

# %%
dataset.isnull().sum()
# Out:
# name                   0
# school_rating          0
# size                   0
# reduced_lunch          0
# state_percentile_16    0
# state_percentile_15    6
# stu_teach_ratio        0
# school_type            0
# avg_score_15           6
# avg_score_16           0
# full_time_teachers     0
# percent_black          0
# percent_white          0
# percent_asian          0
# percent_hispanic       0
# dtype: int64

# %%
dataset["state_percentile_15"].fillna(0,inplace=True)
dataset["avg_score_15"].fillna(0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# name                   0
# school_rating          0
# size                   0
# reduced_lunch          0
# state_percentile_16    0
# state_percentile_15    0
# stu_teach_ratio        0
# school_type            0
# avg_score_15           0
# avg_score_16           0
# full_time_teachers     0
# percent_black          0
# percent_white          0
# percent_asian          0
# percent_hispanic       0
# dtype: int64
